# %% [markdown]
# ### End-to-End Development of ML Application

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split

# %%
warnings.simplefilter("ignore")
data_file = "./data.csv"
df = pd.read_csv(data_file)

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.shape
# Out:
# (44, 14)

# %%
df["thal"] = df["thal"].astype("category").cat.codes

# %%
df["thal"].unique()
# Out:
# array([0, 1, 2], dtype=int8)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop("target", axis=1),
    df["target"],
    test_size=0.1)

# %%
X_train.shape
# Out:
# (39, 13)

# %%
X_test.shape
# Out:
# (5, 13)

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric="logloss")

# %%
model.fit(X_train, y_train,
          eval_set=[(X_test, y_test)],
          verbose=True)
# Out:
# [0]	validation_0-logloss:0.58537
# [1]	validation_0-logloss:0.65588
# [2]	validation_0-logloss:0.52498
# [3]	validation_0-logloss:0.58674
# [4]	validation_0-logloss:0.58869
# [5]	validation_0-logloss:0.64294
# [6]	validation_0-logloss:0.56684
# [7]	validation_0-logloss:0.56922
# [8]	validation_0-logloss:0.59795
# [9]	validation_0-logloss:0.52356
# [10]	validation_0-logloss:0.49689
# [11]	validation_0-logloss:0.47693
# [12]	validation_0-logloss:0.49765
# [13]	validation_0-logloss:0.48598
# [14]	validation_0-logloss:0.46120
# [15]	validation_0-logloss:0.47999
# [16]	validation_0-logloss:0.46507
# [17]	validation_0-logloss:0.41900
# [18]	validation_0-logloss:0.40659
# [19]	validation_0-logloss:0.42255
# [20]	validation_0-logloss:0.41140
# [21]	validation_0-logloss:0.39812
# [22]	validation_0-logloss:0.41146
# [23]	validation_0-logloss:0.40209
# [24]	validation_0-logloss:0.41865
# [25]	validation_0-logloss:0.43374
# [26]	validation_0-logloss:0.43083
# [27]	validation_0-logloss:0.42049
# [28]	validation_0-logloss:0.40926
# [29]	validation_0-logloss:0.42133
# [30]	validation_0-logloss:0.41269
# [31]	validation_0-logloss:0.40993
# [32]	validation_0-logloss:0.40068
# [33]	validation_0-logloss:0.39351
# [34]	validation_0-logloss:0.40510
# [35]	validation_0-logloss:0.40285
# [36]	validation_0-logloss:0.39122
# [37]	validation_0-logloss:0.38313
# [38]	validation_0-logloss:0.37686
# [39]	validation_0-logloss:0.37532
# [40]	validation_0-logloss:0.38331
# [41]	validation_0-logloss:0.37622
# [42]	validation_0-logloss:0.37530
# [43]	validation_0-logloss:0.36975
# [44]	validation_0-logloss:0.36388
# [45]	validation_0-logloss:0.36784
# [46]	validation_0-logloss:0.36708
# [47]	validation_0-logloss:0.36222
# [48]	validation_0-logloss:0.36612
# [49]	validation_0-logloss:0.36145
# [50]	validation_0-logloss:0.36510
# [51]	validation_0-logloss:0.35976
# [52]	validation_0-logloss:0.35538
# [53]	validation_0-logloss:0.35466
# [54]	validation_0-logloss:0.35793
# [55]	validation_0-logloss:0.35354
# [56]	validation_0-logloss:0.35694
# [57]	validation_0-logloss:0.35267
# [58]	validation_0-logloss:0.35584
# [59]	validation_0-logloss:0.35166
# [60]	validation_0-logloss:0.35498
# [61]	validation_0-logloss:0.35819
# [62]	validation_0-logloss:0.35394
# [63]	validation_0-logloss:0.35710
# [64]	validation_0-logloss:0.36181
# [65]	validation_0-logloss:0.36134
# [66]	validation_0-logloss:0.35745
# [67]	validation_0-logloss:0.36091
# [68]	validation_0-logloss:0.35711
# [69]	validation_0-logloss:0.36041
# [70]	validation_0-logloss:0.35542
# [71]	validation_0-logloss:0.35469
# [72]	validation_0-logloss:0.35021
# [73]	validation_0-logloss:0.34989
# [74]	validation_0-logloss:0.34609
# [75]	validation_0-logloss:0.34946
# [76]	validation_0-logloss:0.34575
# [77]	validation_0-logloss:0.34889
# [78]	validation_0-logloss:0.34540
# [79]	validation_0-logloss:0.34877
# [80]	validation_0-logloss:0.34531
# [81]	validation_0-logloss:0.34850
# [82]	validation_0-logloss:0.34509
# [83]	validation_0-logloss:0.34814
# [84]	validation_0-logloss:0.34770
# [85]	validation_0-logloss:0.35224
# [86]	validation_0-logloss:0.34870
# [87]	validation_0-logloss:0.35186
# [88]	validation_0-logloss:0.34855
# [89]	validation_0-logloss:0.35174
# [90]	validation_0-logloss:0.34845
# [91]	validation_0-logloss:0.35148
# [92]	validation_0-logloss:0.34711
# [93]	validation_0-logloss:0.34689
# [94]	validation_0-logloss:0.34594
# [95]	validation_0-logloss:0.34891
# [96]	validation_0-logloss:0.34515
# [97]	validation_0-logloss:0.34106
# [98]	validation_0-logloss:0.34389
# [99]	validation_0-logloss:0.34039
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score

# %%
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
print(f"Accuracy : {accuracy}, Recall: {recall}")
# Out:
# Accuracy : 0.8, Recall: 0.5
